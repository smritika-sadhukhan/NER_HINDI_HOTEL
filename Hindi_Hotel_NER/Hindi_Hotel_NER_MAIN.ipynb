# %%
from Testing_hindi_hotel_NER import predict_NER

# %%
from Hotel_Hindi_NER.util.Testing_hindi_hotel_NER import prediction

# %%
data= ["मुझे 2 लोग के लिए मुंबई में एक कमरा दिलवाएं",
 'क्या समय चेक-इन समय है',
 'मैं 5 मार्च के लिए होटल के लिए अपनी बुकिंग रद्द करना चाहता हूं',
 'क्या आप मुझे बर्लिन में 2 लोगों के लिए एक होटल दिलवा सकते हैं'
 'मुझे 5 मार्च को कुचिपुड़ी में एक होटल चाहिए',
 '15 अगस्त के लिए मुझे नई दिल्ली में 2 के लिए एक होटल चाहिए',
 'रियो डी जेनेरियो में मुझे होटल दिखाएं',
 "नाम से होटल क्रमबद्ध करें",
 "मूल्य द्वारा होटल दिखाएं",
 "हाँ, कृपया भुगतान करें",
 "शनिवार को नई दिल्ली में 2 लोगों के रहने की कीमत क्या है",
 "हां बुक करो",
 "मुझे म्यूनिख में 5 सितारा होटल दिखाएं",
 "15 अगस्त के लिए मुझे 4 सितारा होटल दिखाएं",
 'मुझे 5000 की रेंज में सभी 4 स्टार रेटेड होटल दिखाएं',
'मुझे प्रति रात 5000 से कम लागत वाले होटल दिखाएं',
'मुझे होटल ताज, मुंबई में एक शानदार कमरा चाहिए',
"महान ओबेरॉय में युगल सूट बुक करें",
"स्विमिंग पूल की सुविधाओं के साथ मुझे होटल दिखाएं",
"फ्री इंटरनेट और स्विमिंग पूल जैसी सुविधाएं प्रदान करने वाले होटल दिखाएं",
"मुझे 17 अगस्त की सुबह 6 बजे ताज से चेकआउट करने की आवश्यकता है",
 ]

# %%
predict_NER(data)
# Out:
#
# मुझे            O
# 2               B-NoOfTravellers
# लोग             O
# के              O
# लिए             O
# मुंबई           B-Location
# में             O
# एक              O
# कमरा            O
# दिलवाएं         O
# --------------------------------------------------
#
# क्या            O
# समय             O
# चेक-इन          O
# समय             B-Amenities
# है              O
# --------------------------------------------------
#
# मैं             O
# 5               B-checkin
# मार्च           I-checkin
# के              O
# लिए             O
# होटल            O
# के              O
# लिए             O
# अपनी            O
# बुकिंग          O
# रद्द            O
# करना            O
# चाहता           O
# हूं             O
# --------------------------------------------------
#
# क्या            O
# आप              O
# मुझे            O
# बर्लिन          B-Location
# में             O
# 2               O
# लोगों           O
# के              O
# लिए             O
# ...
